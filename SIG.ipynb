# %%
# %matplotlib inline
#pacote para visualização gráfica
import matplotlib.pyplot as plt
#pacote para trabalhar com matrizes
from matplotlib.gridspec import GridSpec
import numpy as np
#pacote para importar e exportar dados e trabalhar comd dataframes
import pandas as pd
import math
def init_plotting(x=25,y=23):
    plt.rcParams['figure.figsize'] = (x,y)
    plt.rcParams['font.size'] = 25
    plt.rcParams['font.family'] = 'ubuntu'
    plt.rcParams['axes.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['axes.titlesize'] = 1*plt.rcParams['font.size']
    plt.rcParams['legend.fontsize'] = 0.65*plt.rcParams['font.size']
    plt.rcParams['xtick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['ytick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.minor.size'] = 3
    plt.rcParams['xtick.major.width'] = 1
    plt.rcParams['xtick.minor.width'] = 1
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.minor.size'] = 3
    plt.rcParams['ytick.major.width'] = 1
    plt.rcParams['ytick.minor.width'] = 1
    plt.rcParams['legend.frameon'] = True
    plt.rcParams['legend.loc'] = 'best'
    plt.rcParams['axes.linewidth'] = 1
init_plotting()

# %%
sig = pd.read_table("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/tabelas_artigos/SIG/SIG+SDSS.csv", sep=",")
#df = pd.DataFrame(np.nan, index = np.arange(len(data.dered_g)), columns = ['ra', 'dec', 'SIG', 'dered_g', 'M_g',
#                                                                           'dered_r', 'M_r', 'z', 'kcorr_g', 
#                                                                           'kcorr_r', 'DM', 'lgm_tot_p50',
#                                                                           'sfr_tot_p50', 'd_NN', 'eta_k_LSS', 
#                                                                           'Q_LSS', 'k_LSS'])
sig.columns
# Out:
# Index(['objID_1', 'ra_1', 'dec_1', 'dered_u', 'dered_g', 'dered_r', 'dered_i',
#        'dered_z', 'z_1', 'zErr', 'petroR50_r', 'petroR90_r', 'petroR50_i',
#        'petroR90_ri', 'fracDeV_r', 'fracDeV_i', 'photo_z', 'photo_zerr',
#        'kcorr_u', 'kcorr_g', 'kcorr_r', 'kcorr_i', 'kcorr_z', 'bptclass',
#        'oh_p50', 'lgm_tot_p50', 'sfr_tot_p50', 'specsfr_tot_p50', 'SIG_1',
#        'ra_1a', 'dec_1a', 'z_1a', 'k_LSS', 'f_LSS', 'd_NN', 'eta_k_LSS',
#        'Q_LSS', 'separation_1', 'SIG_2', 'objID_2', 'ra_2', 'dec_2', 'absMagG',
#        'absMagR', 'Separation'],
#       dtype='object')

# %%
#Esse cáculo falhou

c = 299792.458 #km/s
omega_m = 0.3
for i in range(len(data.dered_g)): 
    a = 2*c
    b = 70*omega_m*(10**6)
    c = 2 - omega_m*(1 - data.z[0]) - (2 - omega_m)*math.sqrt(1 - 0.3*data.z[0])   
    
    df.ra[i] = data.ra[i]; df.dec[i] = data.dec[i]; df.SIG[i] = int(data.SIG[i]); df.dered_g[i] = data.dered_g[i] 
    df.dered_r[i] = data.dered_r[i]; df.z[i] = data.z[i]; df.kcorr_g[i] = data.kcorr_g[i]
    df.kcorr_r[i] = data.kcorr_r[i]; df.lgm_tot_p50[i] = data.lgm_tot_p50[i]
    df.sfr_tot_p50[i] = data.sfr_tot_p50[i]; df.d_NN[i] = data.d_NN[i]; df.eta_k_LSS[i] = data.eta_k_LSS[i]
    df.Q_LSS[i] = data.Q_LSS[i]; df.k_LSS[i] = data.k_LSS[i]
    
    df.DM[i] = 5*math.log10((a*c)/(10*b))
    
    df.M_g[i] = df.dered_g[i] - df.DM[i] - df.kcorr_g[i]
    df.M_r[i] = df.dered_r[i] - df.DM[i] - df.kcorr_r[i]

# %%
plt.figure()
plt.scatter(sig.k_LSS, sig.absMagG - sig.absMagR) # scatter plot
plt.xlabel("K$_{LSS}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.xlim(0, 250)
plt.ylim(-0.1, 1.4)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/k_vs_cor.png") # Saves the figure

plt.figure()
plt.subplot(2,2,1)
plt.scatter(sig.k_LSS, sig.absMagG - sig.absMagR)
plt.xlabel("") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.xlim(0, 50)
plt.ylim(-0.1, 1.4)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito

plt.subplot(2,2,2)
plt.scatter(sig.k_LSS, sig.absMagG - sig.absMagR)
plt.xlabel("") 
plt.ylabel("") 
plt.title("", fontweight='bold') 
plt.xlim(50, 100)
plt.ylim(-0.1, 1.4)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito

plt.subplot(2,2,3)
plt.scatter(sig.k_LSS, sig.absMagG - sig.absMagR)
plt.xlabel("K$_{LSS}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.xlim(100, 150)
plt.ylim(-0.1, 1.4)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito

plt.subplot(2,2,4)
plt.scatter(sig.k_LSS, sig.absMagG - sig.absMagR)
plt.xlabel("K$_{LSS}$") 
plt.ylabel("") 
plt.title("", fontweight='bold') 
plt.xlim(150, 200)
plt.ylim(-0.1, 1.4)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito

plt.subplots_adjust(hspace=0.2) # adjusts the horizontal space between the subplots

#plt.legend(("Nao-ETG", "ETG", "riguccini+15", "possible miegs"))
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/k_vs_cor-subplots.png") # Saves the figure

# %%
plt.figure()
plt.scatter(sig.k_LSS, sig.sfr_tot_p50) # scatter plot
plt.xlabel("K$_{LSS}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.xlim(0, 250)
plt.ylim(-3, 3)
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/k_vs_SFR.png") # Saves the figure

plt.figure()
plt.subplot(2,2,1)
plt.scatter(sig.k_LSS, sig.sfr_tot_p50) # scatter plot
plt.xlabel("") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.xlim(0, 50)
plt.ylim(-3, 3)

plt.subplot(2,2,2)
plt.scatter(sig.k_LSS, sig.sfr_tot_p50) # scatter plot
plt.xlabel("") 
plt.ylabel("") 
plt.title("", fontweight='bold') 
plt.xlim(50, 100)
plt.ylim(-3, 3)

plt.subplot(2,2,3)
plt.scatter(sig.k_LSS, sig.sfr_tot_p50) # scatter plot
plt.xlabel("K$_{LSS}$") 
plt.ylabel("Log(SFR)") 
plt.title("", fontweight='bold') 
plt.xlim(100, 150)
plt.ylim(-3, 3)

plt.subplot(2,2,4)
plt.scatter(sig.k_LSS, sig.sfr_tot_p50) # scatter plot
plt.xlabel("K$_{LSS}$") 
plt.ylabel("") 
plt.title("", fontweight='bold') 
plt.xlim(150, 200)
plt.ylim(-3, 3)

plt.subplots_adjust(hspace=0.2) # adjusts the horizontal space between the subplots
#plt.legend(("Nao-ETG", "ETG", "riguccini+15", "possible miegs"))
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/k_vs_SFR-subplots.png") # Saves the figure

# %%
plt.figure()
plt.scatter(sig.k_LSS, sig.lgm_tot_p50) # scatter plot
plt.xlabel("K$_{LSS}$") 
plt.ylabel("Log (M*)") 
plt.title("", fontweight='bold') 
plt.xlim(0, 250)
plt.ylim(8, 12)
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/k_vs_M.png") # Saves the figure

plt.figure()
plt.subplot(2,2,1)
plt.scatter(sig.k_LSS, sig.lgm_tot_p50) # scatter plot
plt.xlabel("") 
plt.ylabel("Log (M*)") 
plt.title("", fontweight='bold') 
plt.xlim(0, 50)
plt.ylim(8, 12)

plt.subplot(2,2,2)
plt.scatter(sig.k_LSS, sig.lgm_tot_p50) # scatter plot
plt.xlabel("") 
plt.ylabel("") 
plt.title("", fontweight='bold') 
plt.xlim(50, 100)
plt.ylim(8, 12)

plt.subplot(2,2,3)
plt.scatter(sig.k_LSS, sig.lgm_tot_p50) # scatter plot
plt.xlabel("K$_{LSS}$") 
plt.ylabel("Log(M*)") 
plt.title("", fontweight='bold') 
plt.xlim(100, 150)
plt.ylim(8, 12)

plt.subplot(2,2,4)
plt.scatter(sig.k_LSS, sig.lgm_tot_p50) # scatter plot
plt.xlabel("K$_{LSS}$") 
plt.ylabel("") 
plt.title("", fontweight='bold') 
plt.xlim(150, 200)
plt.ylim(8, 12)

plt.subplots_adjust(hspace=0.2) # adjusts the horizontal space between the subplots
#plt.legend(("Nao-ETG", "ETG", "riguccini+15", "possible miegs"))
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/k_vs_M-subplots.png") # Saves the figure

# %%
cor = sig.absMagG - sig.absMagR
plt.figure()
plt.scatter(sig.eta_k_LSS, cor) # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.xlim(-3, 0)
plt.ylim(-0.2,1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/eta/eta_vs_cor.png") # Saves the figure

# %%
plt.figure()
plt.scatter(sig.eta_k_LSS, sig.sfr_tot_p50) # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.xlim(-3, 0)
plt.ylim(-3, 3)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/eta/eta_vs_SFR.png") # Saves the figure

# %%
plt.figure()
plt.scatter(sig.eta_k_LSS, sig.lgm_tot_p50) # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("Log (M$_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.xlim(-3, 0)
plt.ylim(6,12 )
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/eta/eta_vs_M.png") # Saves the figure

# %%
sig.columns
# Out:
# Index(['objID ', 'ra', 'dec', 'dered_u', 'dered_g', 'dered_r', 'dered_i',
#        'dered_z', 'z', 'zErr', 'petroR50_r ', 'petroR90_r ', 'petroR50_i ',
#        'petroR90_ri', 'fracDeV_r', 'fracDeV_i', 'photo_z', 'photo_zerr',
#        ' kcorr_u', 'kcorr_g', 'kcorr_r', 'kcorr_i', 'kcorr_z', 'bptclass',
#        'oh_p50', 'lgm_tot_p50', 'sfr_tot_p50', 'specsfr_tot_p50', 'SIG',
#        'ra.1', 'dec.1', 'z.1', 'k_LSS', 'f_LSS', 'd_NN', 'eta_k_LSS', 'Q_LSS',
#        'separation'],
#       dtype='object')

# %%
plt.figure()
plt.scatter(sig.Q_LSS, cor) # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
#plt.xlim(-3, 0)
plt.ylim(-0.2, 1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/Q/Q_vs_cor.png") # Saves the figure

# %%
plt.figure()
plt.scatter(sig.Q_LSS, sig.sfr_tot_p50) # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.ylim(-3, 3)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/Q/Q_vs_SFR.png") # Saves the figure

# %%
plt.figure()
plt.scatter(sig.Q_LSS, sig.lgm_tot_p50) # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("Log ($M_{estellar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(6, 12)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIG/Q/Q_vs_M.png") # Saves the figure
