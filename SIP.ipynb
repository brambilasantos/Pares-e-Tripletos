# %%
# %matplotlib inline
#pacote para visualização gráfica
import matplotlib.pyplot as plt
#pacote para trabalhar com matrizes
from matplotlib.gridspec import GridSpec
import numpy as np
#pacote para importar e exportar dados e trabalhar comd dataframes
import pandas as pd
import math
def init_plotting(x=25,y=23):
    plt.rcParams['figure.figsize'] = (x,y)
    plt.rcParams['font.size'] = 25
    plt.rcParams['font.family'] = 'ubuntu'
    plt.rcParams['axes.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['axes.titlesize'] = 1*plt.rcParams['font.size']
    plt.rcParams['legend.fontsize'] = 0.65*plt.rcParams['font.size']
    plt.rcParams['xtick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['ytick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.minor.size'] = 3
    plt.rcParams['xtick.major.width'] = 1
    plt.rcParams['xtick.minor.width'] = 1
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.minor.size'] = 3
    plt.rcParams['ytick.major.width'] = 1
    plt.rcParams['ytick.minor.width'] = 1
    plt.rcParams['legend.frameon'] = True
    plt.rcParams['legend.loc'] = 'best'
    plt.rcParams['axes.linewidth'] = 1
init_plotting()

# %%
sip = pd.read_csv('/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/tabelas_artigos/SIP/SIP_3D_SDSS+SIP_environment+SDSS.csv')

# %%
sip.columns
# Out:
# Index(['SIP_1', 'index', 'ra_1', 'dec_1', 'z_1', 'SIP_1a', 'k_LSS', 'f_LSS',
#        'd_NN', 'eta_k_LSS', 'Q_LSS', 'Q_pair', 'Q_pair_Q_total', 'objID_1',
#        'ra_2', 'dec_2', 'dered_u', 'dered_g', 'dered_r', 'dered_i', 'dered_z',
#        'z_2', 'zErr', 'petroR50_r', 'petroR90_r', 'petroR50_i', 'petroR90_i',
#        'fracDeV_r', 'fracDeV_i', 'photo_z', 'photo_zerr', 'kcorr_u', 'kcorr_g',
#        'kcorr_r', 'kcorr_i', 'kcorr_z', 'bptclass', 'oh_p50', 'lgm_tot_p50',
#        'sfr_tot_p50', 'specsfr_tot_p50', 'Separation_1', 'SIP', 'objID_2',
#        'ra', 'dec', 'absMagG', 'absMagR', 'Separation'],
#       dtype='object')

# %%
plt.figure()
plt.scatter(sip.Q_LSS, sip.sfr_tot_p50, color = 'red', marker = '^') # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.ylim(-4.5, 2)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/Q_LSS/Qlss_vs_SFR.png")

# %%
cor = sip.absMagG - sip.absMagR
plt.figure()
plt.scatter(sip.Q_LSS, cor, color = 'red', marker = '^') # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.ylim(-0.25, 1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/Q_LSS/Qlss_vs_cor.png")

# %%
plt.figure()
plt.scatter(sip.Q_LSS, sip.lgm_tot_p50, color = 'red', marker = '^') # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("Log (M$_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(6, 12)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/Q_LSS/Qlss_vs_M.png")

# %%
plt.figure()
plt.scatter(sip.Q_pair, sip.lgm_tot_p50, color = 'red', marker = '^') # scatter plot
plt.xlabel("Q$_{pair}$") 
plt.ylabel("Log (M$_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(6, 12)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/Q_pair/Qp_vs_M.png")

# %%
plt.figure()
plt.scatter(sip.Q_pair, cor, color = 'red', marker = '^') # scatter plot
plt.xlabel("Q$_{pair}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.ylim(-0.25, 1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/Q_pair/Qp_vs_cor.png")

# %%
plt.figure()
plt.scatter(sip.Q_pair, sip.sfr_tot_p50, color = 'red', marker = '^') # scatter plot
plt.xlabel("Q$_{pair}$") 
plt.ylabel("Log (SFR)")
plt.title("", fontweight='bold') 
plt.ylim(-4.5, 2)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/Q_pair/Qp_vs_SFR.png")

# %%
plt.figure()
plt.scatter(sip.eta_k_LSS, sip.sfr_tot_p50, color = 'red', marker = '^') # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.ylim(-4.5, 2)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/eta/eta_vs_SFR.png")

# %%
plt.figure()
plt.scatter(sip.eta_k_LSS, cor, color = 'red', marker = '^') # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.ylim(-.25, 1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/eta/eta_vs_cor.png")

# %%
plt.figure()
plt.scatter(sip.eta_k_LSS, sip.lgm_tot_p50, color = 'red', marker = '^') # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("Log (M$_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(6, 12)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIP/eta/eta_vs_M.png")
