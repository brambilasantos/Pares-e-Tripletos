# %%
# %matplotlib inline
#pacote para visualização gráfica
import matplotlib.pyplot as plt
#pacote para trabalhar com matrizes
from matplotlib.gridspec import GridSpec
import numpy as np
#pacote para importar e exportar dados e trabalhar comd dataframes
import pandas as pd
import math
def init_plotting(x=25,y=23):
    plt.rcParams['figure.figsize'] = (x,y)
    plt.rcParams['font.size'] = 25
    plt.rcParams['font.family'] = 'ubuntu'
    plt.rcParams['axes.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['axes.titlesize'] = 1*plt.rcParams['font.size']
    plt.rcParams['legend.fontsize'] = 0.65*plt.rcParams['font.size']
    plt.rcParams['xtick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['ytick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.minor.size'] = 3
    plt.rcParams['xtick.major.width'] = 1
    plt.rcParams['xtick.minor.width'] = 1
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.minor.size'] = 3
    plt.rcParams['ytick.major.width'] = 1
    plt.rcParams['ytick.minor.width'] = 1
    plt.rcParams['legend.frameon'] = True
    plt.rcParams['legend.loc'] = 'best'
    plt.rcParams['axes.linewidth'] = 1
init_plotting()

sit = pd.read_csv('/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/tabelas_artigos/SIT/SIT_environment+SDSS.csv')

# %%
sit.columns
# Out:
# Index(['SIT_1', 'index', 'ra_1', 'dec_1', 'z_1', 'SIT_1a', 'k_LSS', 'f_LSS',
#        'd_NN', 'eta_k-LSS', 'Q_LSS', 'Q_triplet', 'Q_triplet/Q_total',
#        'objID_1', 'ra_2', 'dec_2', 'dered_u', 'dered_g', 'dered_r', 'dered_i',
#        'dered_z', 'z_2', 'zErr', 'petroR50_r', 'petroR90_r', 'petroR50_i',
#        'petroR90_i', 'fracDeV_r', 'fracDeV_i', 'photo_z', 'photo_zerr',
#        'kcorr_u', 'kcorr_g', 'kcorr_r', 'kcorr_i', 'kcorr_z', 'bptclass',
#        'oh_p50', 'lgm_tot_p50', 'sfr_tot_p50', 'specsfr_tot_p50',
#        'Separation_1', 'SIT', 'objID_2', 'ra', 'dec', 'absMagG', 'absMagR',
#        'Separation'],
#       dtype='object')

# %%
plt.figure()
plt.scatter(sit.Q_LSS, sit.sfr_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.ylim(-2.6, 1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_LSS/Qlss_vs_SFR.png")

# %%
cor = sit.absMagG - sit.absMagR
plt.figure()
plt.scatter(sit.Q_LSS, cor, color = 'green', marker = 's') # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.ylim(0, 1)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_LSS/Qlss_vs_cor.png")

# %%
plt.figure()
plt.scatter(sit.Q_LSS, sit.lgm_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("Q$_{LSS}$") 
plt.ylabel("Log ($M_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(7, 12)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_LSS/Qlss_vs_M.png")

# %%
plt.figure()
plt.scatter(sit.eta_k_LSS, cor, color = 'green', marker = 's') # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.ylim(0, 1)
plt.xlim(-3, 0)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/eta/eta_vs_cor.png")

# %%
plt.figure()
plt.scatter(sit.eta_k_LSS, sit.sfr_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.ylim(-3,1.5)
plt.xlim(-3, 0)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/eta/eta_vs_SFR.png")

# %%
plt.figure()
plt.scatter(sit.eta_k_LSS, sit.lgm_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("$\eta_{K_{LSS}}$") 
plt.ylabel("Log ($M_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(7,12)
plt.xlim(-3, 0)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/eta/eta_vs_M.png")

# %%
plt.figure()
plt.scatter(sit.Q_triplet, cor, color = 'green', marker = 's') # scatter plot
plt.xlabel("$Q_{triplet}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.ylim(0, 1)
#plt.xlim(-3, 0)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_triplet/Qt_vs_cor.png")

# %%
plt.figure()
plt.scatter(sit.Q_triplet, sit.sfr_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("$Q_{triplet}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.ylim(-3,1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_triplet/Qt_vs_SFR.png")

# %%
plt.figure()
plt.scatter(sit.Q_triplet, sit.lgm_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("$Q_{triplet}$") 
plt.ylabel("Log ($M_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(7,12)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_triplet/Qt_vs_M.png")

# %%
plt.figure()
plt.scatter(sit.Q_triplet_Q_total, cor, color = 'green', marker = 's') # scatter plot
plt.xlabel("$Q_{triplet}/Q_{total}$") 
plt.ylabel("g - r") 
plt.title("", fontweight='bold') 
plt.ylim(0, 1)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_ratio/Qr_vs_cor.png")

# %%
plt.figure()
plt.scatter(sit.Q_triplet_Q_total, sit.sfr_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("$Q_{triplet}$") 
plt.ylabel("Log (SFR)") 
plt.title("", fontweight='bold') 
plt.ylim(-3,1.5)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_ratio/Qr_vs_SFR.png")

# %%
plt.figure()
plt.scatter(sit.Q_triplet_Q_total, sit.lgm_tot_p50, color = 'green', marker = 's') # scatter plot
plt.xlabel("$Q_{triplet}$") 
plt.ylabel("Log ($M_{estelar}$)") 
plt.title("", fontweight='bold') 
plt.ylim(7,12)
plt.gca().spines["top"].set_visible(False) #apaga o "eixo" superior
plt.gca().spines["right"].set_visible(False) #apaga o "eixo" direito
plt.savefig("/home/douglas/Documentos/IC-Paulo/Pares_e_Tripletos/Graficos/SIT/Q_ratio/Qr_vs_M.png")
